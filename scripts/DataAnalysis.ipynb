# %%
import glob

# %%
files = glob.glob("C:/Users/20221051/Downloads/tempdataset/svla_so100_pickplace/data/chunk-000/*.parquet")
df = pd.concat([pd.read_parquet(f) for f in files], ignore_index=True)
print(df.head())
# Out:
# Running cells with '.venv (3.12.6) (Python 3.12.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/20221051/Documents/GitHub/RandomVisualization/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
